# %%
# !pip install mediapipe opencv-python pandas scikit-learn
# Out:
# Requirement already satisfied: mediapipe in c:\users\fatema\appdata\roaming\python\python39\site-packages (0.10.9)
# Requirement already satisfied: opencv-python in c:\users\fatema\anaconda3\lib\site-packages (4.9.0.80)
# Requirement already satisfied: pandas in c:\users\fatema\anaconda3\lib\site-packages (1.4.4)
# Requirement already satisfied: scikit-learn in c:\users\fatema\anaconda3\lib\site-packages (1.0.2)
# Requirement already satisfied: numpy in c:\users\fatema\anaconda3\lib\site-packages (from mediapipe) (1.24.4)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\fatema\anaconda3\lib\site-packages (from mediapipe) (23.5.26)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\fatema\anaconda3\lib\site-packages (from mediapipe) (21.4.0)
# Requirement already satisfied: protobuf<4,>=3.11 in c:\users\fatema\anaconda3\lib\site-packages (from mediapipe) (3.20.3)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\fatema\appdata\roaming\python\python39\site-packages (from mediapipe) (0.4.6)
# Requirement already satisfied: matplotlib in c:\users\fatema\anaconda3\lib\site-packages (from mediapipe) (3.5.2)
# Requirement already satisfied: opencv-contrib-python in c:\users\fatema\appdata\roaming\python\python39\site-packages (from mediapipe) (4.9.0.80)
# Requirement already satisfied: absl-py in c:\users\fatema\appdata\roaming\python\python39\site-packages (from mediapipe) (2.1.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\fatema\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\fatema\anaconda3\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\fatema\anaconda3\lib\site-packages (from scikit-learn) (1.9.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\fatema\anaconda3\lib\site-packages (from scikit-learn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\fatema\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\fatema\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: CFFI>=1.0 in c:\users\fatema\anaconda3\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.15.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\fatema\anaconda3\lib\site-packages (from matplotlib->mediapipe) (1.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\fatema\anaconda3\lib\site-packages (from matplotlib->mediapipe) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\fatema\anaconda3\lib\site-packages (from matplotlib->mediapipe) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\fatema\anaconda3\lib\site-packages (from matplotlib->mediapipe) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\fatema\anaconda3\lib\site-packages (from matplotlib->mediapipe) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\fatema\anaconda3\lib\site-packages (from matplotlib->mediapipe) (3.0.9)
# Requirement already satisfied: pycparser in c:\users\fatema\anaconda3\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)

# %%
import mediapipe as mp
import cv2
import numpy as np
# Out:
# WARNING:tensorflow:From C:\Users\Fatema\anaconda3\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
mp_pose = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %% [markdown]
# Make some detections

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened() :
        ret, image = cap.read()
        print('hello inside capture')
        # Recolor Feed
        image = cv2.cvtColor (image, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        # Make Detections
        results = pose.process (image)
        # Recolor image back to BGR for rendering
        image.flags.writeable = True
        image = cv2. cvtColor(image, cv2.COLOR_RGB2BGR)
        mp_drawing.draw_landmarks(
            image,
            results.pose_landmarks,
            mp_pose.POSE_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=4),
            mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2)
        )
        
        cv2.imshow('Raw Webcam Feed' , image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
        
cap.release()
cv2.destroyAllWindows()
# Out:
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture
# hello inside capture

# %%
cap = cv2.VideoCapture(0)

height = cap.get(cv2.CAP_PROP_FRAME_HEIGHT)
width = cap.get(cv2.CAP_PROP_FRAME_WIDTH)
fps = cap.get(cv2.CAP_PROP_FPS)
videoWriter = cv2.VideoWriter('press.avi', cv2.VideoWriter_fourcc('P', 'I', 'M','1'), fps, (int(width), int(height)))

while cap.isOpened():
    ret, frame = cap.read()
    
    try: 
        cv2.imshow('Press', frame)
        videoWriter.write(frame)
    except Exception as e:
        breal
        
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

cap.release()
videoWriter.release()
cv2.destroyAllWindows()

# %%
import os

current_directory = os.getcwd()
print("Current Directory:", current_directory)
# Out:
# Current Directory: C:\Users\Fatema\Untitled Folder

# %%
import csv
import os
import numpy as np
from matplotlib import pyplot as plt

# %%
landmarks = ['class']
for val in range(1, 33+1):
    landmarks += ['x{}'.format(val), 'y{}'.format(val), 'z{}'.format(val), 'v{}'.format(val)]

# %%
landmarks[1:]
# Out:
# ['x1',
#  'y1',
#  'z1',
#  'v1',
#  'x2',
#  'y2',
#  'z2',
#  'v2',
#  'x3',
#  'y3',
#  'z3',
#  'v3',
#  'x4',
#  'y4',
#  'z4',
#  'v4',
#  'x5',
#  'y5',
#  'z5',
#  'v5',
#  'x6',
#  'y6',
#  'z6',
#  'v6',
#  'x7',
#  'y7',
#  'z7',
#  'v7',
#  'x8',
#  'y8',
#  'z8',
#  'v8',
#  'x9',
#  'y9',
#  'z9',
#  'v9',
#  'x10',
#  'y10',
#  'z10',
#  'v10',
#  'x11',
#  'y11',
#  'z11',
#  'v11',
#  'x12',
#  'y12',
#  'z12',
#  'v12',
#  'x13',
#  'y13',
#  'z13',
#  'v13',
#  'x14',
#  'y14',
#  'z14',
#  'v14',
#  'x15',
#  'y15',
#  'z15',
#  'v15',
#  'x16',
#  'y16',
#  'z16',
#  'v16',
#  'x17',
#  'y17',
#  'z17',
#  'v17',
#  'x18',
#  'y18',
#  'z18',
#  'v18',
#  'x19',
#  'y19',
#  'z19',
#  'v19',
#  'x20',
#  'y20',
#  'z20',
#  'v20',
#  'x21',
#  'y21',
#  'z21',
#  'v21',
#  'x22',
#  'y22',
#  'z22',
#  'v22',
#  'x23',
#  'y23',
#  'z23',
#  'v23',
#  'x24',
#  'y24',
#  'z24',
#  'v24',
#  'x25',
#  'y25',
#  'z25',
#  'v25',
#  'x26',
#  'y26',
#  'z26',
#  'v26',
#  'x27',
#  'y27',
#  'z27',
#  'v27',
#  'x28',
#  'y28',
#  'z28',
#  'v28',
#  'x29',
#  'y29',
#  'z29',
#  'v29',
#  'x30',
#  'y30',
#  'z30',
#  'v30',
#  'x31',
#  'y31',
#  'z31',
#  'v31',
#  'x32',
#  'y32',
#  'z32',
#  'v32',
#  'x33',
#  'y33',
#  'z33',
#  'v33']

# %%
with open('coords.csv', mode='w', newline='') as f:
    csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    csv_writer.writerow(landmarks)

# %%
def export_landmark(results, action):
    print('hi')
    try: 
        keypoints = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten()
        keypoints = [''] + keypoints.tolist()
        keypoints[0] = action
        print('hi')
        
        with open('coords.csv', mode='a', newline='') as f:
            csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
            csv_writer.writerow(keypoints)
            print('hi')
    except Exception as e:
        print(f"An error occurred: {e}")

# %%
results.pose_landmarks
# Out:
# landmark {
#   x: 0.41287723183631897
#   y: 1.0119231939315796
#   z: -0.6968443989753723
#   visibility: 0.9976937770843506
# }
# landmark {
#   x: 0.42867809534072876
#   y: 0.9729648232460022
#   z: -0.6236115097999573
#   visibility: 0.9964732527732849
# }
# landmark {
#   x: 0.44008174538612366
#   y: 0.972829282283783
#   z: -0.6233313679695129
#   visibility: 0.996087372303009
# }
# landmark {
#   x: 0.45042115449905396
#   y: 0.972848653793335
#   z: -0.6229108572006226
#   visibility: 0.9959532618522644
# }
# landmark {
#   x: 0.3919285535812378
#   y: 0.9724299311637878
#   z: -0.6302968263626099
#   visibility: 0.9969617128372192
# }
# landmark {
#   x: 0.3775850534439087
#   y: 0.9717601537704468
#   z: -0.6299515962600708
#   visibility: 0.9967634677886963
# }
# landmark {
#   x: 0.3634900748729706
#   y: 0.9710450768470764
#   z: -0.6297375559806824
#   visibility: 0.9967640042304993
# }
# landmark {
#   x: 0.4570196270942688
#   y: 0.9950641989707947
#   z: -0.2495468407869339
#   visibility: 0.9918677806854248
# }
# landmark {
#   x: 0.33805596828460693
#   y: 0.9964279532432556
#   z: -0.2766474485397339
#   visibility: 0.9949215054512024
# }
# landmark {
#   x: 0.43322357535362244
#   y: 1.0611211061477661
#   z: -0.5501323342323303
#   visibility: 0.9289292693138123
# }
# landmark {
#   x: 0.3845171332359314
#   y: 1.051351547241211
#   z: -0.5606027245521545
#   visibility: 0.938736617565155
# }
# landmark {
#   x: 0.5631218552589417
#   y: 1.2501059770584106
#   z: -0.1751648485660553
#   visibility: 0.14175376296043396
# }
# landmark {
#   x: 0.24614226818084717
#   y: 1.259371280670166
#   z: -0.16177955269813538
#   visibility: 0.15034346282482147
# }
# landmark {
#   x: 0.6323351860046387
#   y: 1.2066407203674316
#   z: -0.396213173866272
#   visibility: 0.05022580549120903
# }
# landmark {
#   x: 0.2147563248872757
#   y: 1.2119272947311401
#   z: -0.4861401617527008
#   visibility: 0.08540495485067368
# }
# landmark {
#   x: 0.5234987735748291
#   y: 1.090632677078247
#   z: -0.3964511454105377
#   visibility: 0.03278401494026184
# }
# landmark {
#   x: 0.2624043822288513
#   y: 0.9963504076004028
#   z: -0.6977565288543701
#   visibility: 0.05722467973828316
# }
# landmark {
#   x: 0.5031816959381104
#   y: 1.0499457120895386
#   z: -0.4434353709220886
#   visibility: 0.056002531200647354
# }
# landmark {
#   x: 0.31555497646331787
#   y: 0.9502733945846558
#   z: -0.7771037817001343
#   visibility: 0.10189993679523468
# }
# landmark {
#   x: 0.4994335174560547
#   y: 1.0528208017349243
#   z: -0.4141991138458252
#   visibility: 0.07196483761072159
# }
# landmark {
#   x: 0.3037372827529907
#   y: 0.9549049139022827
#   z: -0.7339503765106201
#   visibility: 0.12930290400981903
# }
# landmark {
#   x: 0.5021473169326782
#   y: 1.0684362649917603
#   z: -0.39825528860092163
#   visibility: 0.07617160677909851
# }
# landmark {
#   x: 0.30071213841438293
#   y: 0.981099545955658
#   z: -0.7024313807487488
#   visibility: 0.12295162677764893
# }
# landmark {
#   x: 0.48682913184165955
#   y: 1.9509938955307007
#   z: -0.11998559534549713
#   visibility: 0.0002099217672366649
# }
# landmark {
#   x: 0.3156900703907013
#   y: 1.9371228218078613
#   z: 0.12293509393930435
#   visibility: 0.00021098792785778642
# }
# landmark {
#   x: 0.4566490054130554
#   y: 1.82383394241333
#   z: -0.39554494619369507
#   visibility: 0.00448674988001585
# }
# landmark {
#   x: 0.2521063983440399
#   y: 1.7479749917984009
#   z: -0.11091526597738266
#   visibility: 0.004090381786227226
# }
# landmark {
#   x: 0.4232149124145508
#   y: 2.0497019290924072
#   z: 0.04500364139676094
#   visibility: 0.0010056623723357916
# }
# landmark {
#   x: 0.31517118215560913
#   y: 1.9604544639587402
#   z: 0.16787222027778625
#   visibility: 0.0006419963901862502
# }
# landmark {
#   x: 0.4248073697090149
#   y: 2.106457233428955
#   z: 0.06982943415641785
#   visibility: 0.001209178939461708
# }
# landmark {
#   x: 0.32797032594680786
#   y: 2.0039641857147217
#   z: 0.1993281990289688
#   visibility: 0.0006030037184245884
# }
# landmark {
#   x: 0.393596887588501
#   y: 2.062242031097412
#   z: -0.27354103326797485
#   visibility: 0.004134376998990774
# }
# landmark {
#   x: 0.294211208820343
#   y: 1.9726600646972656
#   z: -0.02965574897825718
#   visibility: 0.002275998704135418
# }

# %%
export_landmark(results, 'up')

# %%
cap = cv2.VideoCapture('press.avi')

with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        
        results = pose.process(image)
        
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                                 mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2)
                                 )
        k = cv2.waitKey(1)
        if k == 117:
            export_landmark(results, 'up')
        if k == 100:
            export_landmark(results, 'down')
            
        cv2.imshow('Raw webcam feed', image)
        
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

cap.release()
cap.destroyAllWindows()
# Out:
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25752\4023163272.py in <module>
#       6         ret, frame = cap.read()
#       7
# ----> 8         image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
#       9         image.flags.writeable = False
#      10
#
# error: OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:196: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
cap.release()
cap.destroyAllWindows()

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
 df = pd.read_csv('coords.csv')

# %%
df.head()
# Out:
#   class        x1        y1        z1        v1        x2        y2        z2  \
# 0    up  0.752296  0.768029 -1.228917  0.999649  0.771991  0.703104 -1.138857
# 1  down  0.740786  0.788132 -1.345729  0.999037  0.767354  0.723029 -1.322725
# 2    up  0.728672  0.790574 -1.395833  0.999393  0.759006  0.722689 -1.376440
# 3  down  0.728123  0.795304 -1.611260  0.999475  0.756810  0.726746 -1.578746
# 4    up  0.737868  0.799760 -1.702002  0.999247  0.762885  0.739571 -1.652016
#
#          v2        x3  ...       z31       v31       x32       y32       z32  \
# 0  0.999664  0.786247  ... -0.125281  0.000058  0.675253  3.273217 -0.370261
# 1  0.996737  0.784680  ...  0.061401  0.000409  0.711025  2.862608 -0.116615
# 2  0.998016  0.776607  ...  0.293226  0.000208  0.670774  2.844024  0.074166
# 3  0.998361  0.774217  ...  0.211176  0.000536  0.687208  2.821807 -0.050212
# 4  0.998216  0.778765  ...  0.819620  0.000407  0.623205  3.008545  0.232817
#
#         v32       x33       y33       z33       v33
# 0  0.000529  0.520887  3.237018 -0.804899  0.000454
# 1  0.001532  0.574856  2.854081 -0.469149  0.000920
# 2  0.001386  0.516444  2.837516 -0.235593  0.001028
# 3  0.002590  0.548254  2.827510 -0.280497  0.002341
# 4  0.002172  0.446608  3.000361  0.234855  0.001711
#
# [5 rows x 133 columns]

# %%
df.tail()
# Out:
#    class        x1        y1        z1        v1        x2        y2  \
# 10  down  0.776397  0.790033 -0.718889  0.999057  0.768719  0.719267
# 11    up  0.758560  0.782231 -0.451476  0.999550  0.766654  0.715182
# 12  down  0.758831  0.784372 -1.125667  0.997207  0.772308  0.713275
# 13    up  0.762148  0.780396 -0.939952  0.996428  0.774919  0.710996
# 14  down  0.757908  0.776790 -1.052972  0.995975  0.774190  0.706449
#
#           z2        v2        x3  ...       z31       v31       x32       y32  \
# 10 -0.683450  0.998942  0.775124  ...  0.152649  0.001483  0.785987  1.626627
# 11 -0.384410  0.999433  0.776641  ...  0.110895  0.001962  0.826447  2.645389
# 12 -1.060271  0.997101  0.787425  ...  0.278105  0.000951  0.799500  3.116941
# 13 -0.853909  0.996272  0.789930  ...  0.081163  0.000586  0.787799  3.309910
# 14 -0.976898  0.995803  0.790417  ...  0.026335  0.000428  0.840134  3.291056
#
#          z32       v32       x33       y33       z33       v33
# 10  0.618376  0.006504  0.845112  1.579730  0.229089  0.005640
# 11  0.069114  0.011971  0.758812  2.641947 -0.154039  0.007956
# 12 -0.179658  0.006086  0.588070  3.110898 -0.112896  0.003986
# 13 -0.267443  0.004048  0.590553  3.302172 -0.490859  0.002572
# 14 -0.297118  0.003145  0.669413  3.278085 -0.547490  0.002007
#
# [5 rows x 133 columns]

# %%
df[df['class']=='up']
# Out:
#    class        x1        y1        z1        v1        x2        y2  \
# 0     up  0.752296  0.768029 -1.228917  0.999649  0.771991  0.703104
# 2     up  0.728672  0.790574 -1.395833  0.999393  0.759006  0.722689
# 4     up  0.737868  0.799760 -1.702002  0.999247  0.762885  0.739571
# 6     up  0.723847  0.800687 -1.693166  0.997866  0.751502  0.734174
# 7     up  0.714571  0.747366 -0.492266  0.998963  0.716777  0.688078
# 9     up  0.694331  0.755790 -0.342176  0.998410  0.719604  0.710133
# 11    up  0.758560  0.782231 -0.451476  0.999550  0.766654  0.715182
# 13    up  0.762148  0.780396 -0.939952  0.996428  0.774919  0.710996
#
#           z2        v2        x3  ...       z31       v31       x32       y32  \
# 0  -1.138857  0.999664  0.786247  ... -0.125281  0.000058  0.675253  3.273217
# 2  -1.376440  0.998016  0.776607  ...  0.293226  0.000208  0.670774  2.844024
# 4  -1.652016  0.998216  0.778765  ...  0.819620  0.000407  0.623205  3.008545
# 6  -1.644910  0.997576  0.768349  ...  1.363163  0.000414  0.586290  3.183188
# 7  -0.446432  0.998504  0.725929  ...  0.141966  0.000154  0.663066  2.940187
# 9  -0.286274  0.998263  0.728367  ... -0.059151  0.000124  0.668089  3.018269
# 11 -0.384410  0.999433  0.776641  ...  0.110895  0.001962  0.826447  2.645389
# 13 -0.853909  0.996272  0.789930  ...  0.081163  0.000586  0.787799  3.309910
#
#          z32       v32       x33       y33       z33       v33
# 0  -0.370261  0.000529  0.520887  3.237018 -0.804899  0.000454
# 2   0.074166  0.001386  0.516444  2.837516 -0.235593  0.001028
# 4   0.232817  0.002172  0.446608  3.000361  0.234855  0.001711
# 6   0.504035  0.001257  0.406108  3.172145  0.769227  0.001449
# 7   0.223137  0.000704  0.526985  2.938451 -0.351448  0.000682
# 9   0.092031  0.000663  0.533061  3.006510 -0.507779  0.000585
# 11  0.069114  0.011971  0.758812  2.641947 -0.154039  0.007956
# 13 -0.267443  0.004048  0.590553  3.302172 -0.490859  0.002572
#
# [8 rows x 133 columns]

# %%
x = df.drop('class', axis=1)
y = df['class']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=1234)

# %%
y_test
# Out:
# 13      up
# 11      up
# 0       up
# 12    down
# 14    down
# Name: class, dtype: object

# %%
import os

# Print the path of the current directory
current_directory = os.getcwd()
print("Current Directory:", current_directory)

# Create the "noaction" folder
parent_folder = current_directory
folder_name = "noaction"
folder_path = os.path.join(parent_folder, folder_name)
os.makedirs(folder_path, exist_ok=True)

# Create 50 empty folders inside "noaction"
for i in range(101, 151):
    folder_name = str(i)
    folder_path = os.path.join(parent_folder, "noaction", folder_name)
    os.makedirs(folder_path, exist_ok=True)

print("Folders created successfully.")

# %% [markdown]
# Train machine learning classification model

# %%
from sklearn.pipeline import make_pipeline 
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LogisticRegression, RidgeClassifier 
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
pipelines = {
    'lr':make_pipeline (StandardScaler(), LogisticRegression()),
    'rc':make_pipeline(StandardScaler(), RidgeClassifier()),
    'rf':make_pipeline (StandardScaler (), RandomForestClassifier()),
    'gb':make_pipeline(StandardScaler(), GradientBoostingClassifier()),
}

# %%
fit_models = {}
for algo, pipeline in pipelines.items():
    model = pipeline.fit(x_train, y_train)
    fit_models[algo] = model

# %%
fit_models
# Out:
# {'lr': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression', LogisticRegression())]),
#  'rc': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('ridgeclassifier', RidgeClassifier())]),
#  'rf': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier', RandomForestClassifier())]),
#  'gb': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('gradientboostingclassifier', GradientBoostingClassifier())])}

# %%
fit_models['rc'].predict(x_test)
# Out:
# array(['down', 'down', 'up', 'down', 'down'], dtype='<U4')

# %% [markdown]
# Evaluate and serialize model

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score # Accuracy metrics 
import pickle

# %%
for algo, model in fit_models.items() :
    yhat = model.predict(x_test)
    print(algo, accuracy_score(y_test.values, yhat),
        precision_score(y_test.values, yhat, average="binary", pos_label="up"), 
        recall_score(y_test.values, yhat, average="binary", pos_label="up"))
# Out:
# lr 0.6 1.0 0.3333333333333333
# rc 0.6 1.0 0.3333333333333333
# rf 0.6 1.0 0.3333333333333333
# gb 0.6 0.6666666666666666 0.6666666666666666

# %%
yhat = fit_models['rf'].predict(x_test)

# %%
yhat[:10]
# Out:
# array(['down', 'down', 'up', 'down', 'down'], dtype=object)

# %%
y_test
# Out:
# 13      up
# 11      up
# 0       up
# 12    down
# 14    down
# Name: class, dtype: object

# %%
with open('squat.pkl', 'wb') as f:
    pickle.dump(fit_models['rf'], f)

# %%
with open('squat.pkl','rb') as f:
    model = pickle.load(f)

# %%
x = pd.DataFrame([row], columns=landmarks[1:])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25752\501232643.py in <module>
# ----> 1 x = pd.DataFrame([row], columns=landmarks[1:])
#
# NameError: name 'row' is not defined

# %%
cap = cv2.VideoCapture(0)
counter = 0
current_stage = ''

with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():
        ret, frame = cap.read()

        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False

        results = pose.process(image)

        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                                  mp_drawing.DrawingSpec(color=(245, 66,230), thickness=2, circle_radius=2)
                                 )
        try:
            row = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten().tolist()        
            X = pd.DataFrame([row], columns=landmarks[1:])
            body_language_class = model.predict(X)[0]
            body_language_prob = model.predict_proba(X)[0]
            print(body_language_class, body_language_prob)

            if body_language_class == 'down' and body_language_prob[body_language_prob.argmax()] >= .7:
                current_stage = 'down'
            elif current_stage == 'down' and body_language_class == 'up' and body_language_prob[body_language_prob.argmax()] < .7:  
                current_stage="up" 
                counter+=1
                print(current_stage)

            cv2.rectangle(image, (0,0), (250, 60), (245, 117, 16), -1)

            cv2.putText(image, 'CLASS',
                       (95, 12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,0), 1, cv2.LINE_AA)
            cv2.putText(image, body_language_class.split(' ')[0],
                       (90,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA )

            cv2.putText(image, 'PROB', 
                       (15,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,0), 1, cv2.LINE_AA)
            cv2.putText(image, str(round(body_language_prob[np.argmax(body_language_prob)], 2)),
                       (10, 40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

            cv2.putText(image, 'COUNT',
                        (180,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,0), 1, cv2.LINE_AA)
            cv2.putText(image, str(counter),
                        (175,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)

            cv2.imshow('Raw Webcam Feed', image)

        except Exception as e:
            print(f"An error occurred: {e}")
            break

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# up [0.36 0.64]
# up [0.36 0.64]
# up [0.34 0.66]
# up [0.34 0.66]
# up [0.28 0.72]
# up [0.31 0.69]
# up [0.31 0.69]
# up [0.29 0.71]
# up [0.3 0.7]
# up [0.26 0.74]
# up [0.31 0.69]
# up [0.35 0.65]
# up [0.36 0.64]
# up [0.35 0.65]
# up [0.33 0.67]
# up [0.35 0.65]
# up [0.31 0.69]
# up [0.35 0.65]
# up [0.36 0.64]
# up [0.37 0.63]
# up [0.36 0.64]
# up [0.37 0.63]
# up [0.36 0.64]
# up [0.4 0.6]
# up [0.41 0.59]
# up [0.42 0.58]
# up [0.4 0.6]
# up [0.42 0.58]
# up [0.44 0.56]
# up [0.45 0.55]
# up [0.46 0.54]
# down [0.5 0.5]
# up [0.49 0.51]
# down [0.51 0.49]
# down [0.5 0.5]
# down [0.51 0.49]
# down [0.5 0.5]
# up [0.48 0.52]
# up [0.48 0.52]
# up [0.49 0.51]
# down [0.5 0.5]
# up [0.46 0.54]
# up [0.46 0.54]
# up [0.42 0.58]
# up [0.3 0.7]
# up [0.33 0.67]
# up [0.35 0.65]
# up [0.31 0.69]
# up [0.33 0.67]
# up [0.36 0.64]
# up [0.43 0.57]
# up [0.43 0.57]
# up [0.46 0.54]
# up [0.44 0.56]
# down [0.5 0.5]
# up [0.41 0.59]
# up [0.42 0.58]
# up [0.4 0.6]
# up [0.46 0.54]
# up [0.43 0.57]
# up [0.43 0.57]
# up [0.44 0.56]
# up [0.43 0.57]
# up [0.43 0.57]
# up [0.43 0.57]
# up [0.44 0.56]
# up [0.4 0.6]
# up [0.44 0.56]
# up [0.43 0.57]
# up [0.42 0.58]
# up [0.43 0.57]
# up [0.44 0.56]
# up [0.41 0.59]
# up [0.38 0.62]
# up [0.34 0.66]
# up [0.36 0.64]
# up [0.39 0.61]
# up [0.4 0.6]
# up [0.41 0.59]
# up [0.33 0.67]
# up [0.4 0.6]
# up [0.4 0.6]
# up [0.38 0.62]
# up [0.39 0.61]
# up [0.37 0.63]
# up [0.39 0.61]
# up [0.36 0.64]
# up [0.36 0.64]
# up [0.38 0.62]
# up [0.42 0.58]
# up [0.48 0.52]
# up [0.43 0.57]
# up [0.45 0.55]
# up [0.47 0.53]
# up [0.45 0.55]
# up [0.41 0.59]
# up [0.35 0.65]
# up [0.35 0.65]
# up [0.38 0.62]
# up [0.33 0.67]
# up [0.32 0.68]
# up [0.3 0.7]
# up [0.37 0.63]
# up [0.41 0.59]
# up [0.4 0.6]
# up [0.35 0.65]
# up [0.36 0.64]
# up [0.36 0.64]
# up [0.42 0.58]
# up [0.41 0.59]
# up [0.42 0.58]
# up [0.38 0.62]
# up [0.37 0.63]
# up [0.42 0.58]
# up [0.44 0.56]
# up [0.47 0.53]
# up [0.47 0.53]
# up [0.43 0.57]
# up [0.41 0.59]
# up [0.41 0.59]
# up [0.41 0.59]
# up [0.43 0.57]
# up [0.43 0.57]
# up [0.45 0.55]
# up [0.39 0.61]
# up [0.38 0.62]
# up [0.42 0.58]
# up [0.42 0.58]
# up [0.35 0.65]
# up [0.42 0.58]
# up [0.39 0.61]
# up [0.39 0.61]
# up [0.42 0.58]
# up [0.4 0.6]
# up [0.39 0.61]
# up [0.39 0.61]
# up [0.36 0.64]
# up [0.39 0.61]
# up [0.37 0.63]
# up [0.38 0.62]
# up [0.35 0.65]
# up [0.34 0.66]
# up [0.34 0.66]
# up [0.33 0.67]
# up [0.34 0.66]
# up [0.32 0.68]
# up [0.33 0.67]
# up [0.35 0.65]
# up [0.35 0.65]
# up [0.35 0.65]
# up [0.35 0.65]
# up [0.35 0.65]

# %%
cap.release()
cv2.destroyAllWindows()
